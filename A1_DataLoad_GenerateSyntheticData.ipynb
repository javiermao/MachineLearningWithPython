# %% [markdown]
# # Generate Synthetic Data
#
# The notebook aims to generate synthetic to study and implement machine learning algorithms.
#
#
# ## Acknowledgments
#
# - Inquiries: mauricio.antelis@tec.mx

# %% [markdown]
# # Importing libraries

# %%
# Import the packages that we will be using
import pandas as pd                 # For data handling
import seaborn as sns               # For advanced plotting
import matplotlib.pyplot as plt     # For showing plots

# Note: specific functions of the "sklearn" package will be imported when needed to show concepts easily

# %% [markdown]
# # Create synthetic data - Option 1

# %%
# Create a dictionary with the data
#d = {'x1': [2, 1, 4, 2, 6, 6, 8, 8],
#     'x2': [2, 3, 3, 4, 6, 5, 5, 6]}

d = {'x1': [2, 4, 2, 6, 6],
     'x2': [2, 3, 4, 6, 5]}

# Construct the dataframe
dataset = pd.DataFrame(data=d)

# %% [markdown]
# Print the generated data

# %%
dataset
# Out:
#    x1  x2
# 0   2   2
# 1   4   3
# 2   2   4
# 3   6   6
# 4   6   5

# %% [markdown]
# Plot a scatter plot

# %%
plt.scatter(dataset.x1,dataset.x2)
plt.title('Data')
plt.xlabel('x1')
plt.ylabel('x2')
plt.show()

# %% [markdown]
# Save the data

# %%
#dataset.to_csv('KmeansSyntheticData5points2Clusters.csv')

# %% [markdown]
# # Create synthetic data - Option 2

# %%
# Import make_blobs
from sklearn.datasets import make_blobs

# Get data
datos = make_blobs(n_samples=1024, centers=4, n_features=6, cluster_std=2.0)
X  = datos[0]
y  = datos[1]

# Construct a dataframe
dfX = pd.DataFrame(X, columns = ['x1','x2','x3','x4','x5','x6'])
dfy = pd.DataFrame(y, columns = ['y'])

# Scatter plot of the first two variables
plt.scatter(X[:,0],X[:,1], s=20)

# Pairplot
g = sns.pairplot(dfX, corner =True, diag_kind="kde")
g.map_lower(sns.kdeplot, levels=4, color=".2")
plt.show()

# Save data
#dfX.to_csv('SyntheticData4Clustering_X.csv')
#dfy.to_csv('SyntheticData4Clustering_y.csv')

# %% [markdown]
# # Create synthetic data - Option 3

# %%
# Import make_moons
from sklearn.datasets import make_moons
from sklearn.datasets import make_circles

# Get data
Z, y = make_moons(1760, noise=.2)
Z, y = make_circles(n_samples=2048, factor=0.8, noise=0.08)

X = Z.copy()

X[:,0] = Z[:,0]
X[:,1] = Z[:,1]

# Scatter plot
plt.scatter(X[:,0],X[:,1], s=12)
plt.xlabel('x1')
plt.ylabel('x2')
plt.show()



# Construt a dataframe
dfX = pd.DataFrame(X, columns = ['x1','x2'])
dfy = pd.DataFrame(y, columns = ['y'])

# Pairplot
g = sns.pairplot(dfX, corner =True, diag_kind="kde")
g.map_lower(sns.kdeplot, levels=4, color=".2")
plt.show()

# Save data
dfX.to_csv('A01640603.csv')
#dfy.to_csv('A01641742_y.csv')

# %% [markdown]
# Save the data

# %%
#dataset.to_csv('A01639036.csv')
